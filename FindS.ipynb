# %%
import pandas as pd

# %%
df = pd.read_csv("data(1).csv")
df
# Out:
#      sky airtemp humidity    wind water forecast enjoy sport
# 0  sunny    warm   normal  strong  warm     same         yes
# 1  sunny    warm     high  strong  warm     same         yes
# 2  rainy    cold     high  strong  warm   change          no
# 3  sunny    warm     high  strong  cool   change         yes

# %%
# FIND S algorithm

specific_hypothesis = ["phi", "phi", "phi", "phi", "phi", "phi"]
for index, row in df.iterrows():
    if (row[len(row.tolist()) - 1] == "yes"):
        print(specific_hypothesis)
        for i in range(0, len(row.tolist()) - 1):
            if (row.isna()[i] == False and specific_hypothesis[i] != row.tolist()[i]):
                specific_hypothesis[i] = row.tolist()[i]
print(specific_hypothesis)
# Out:
# ['phi', 'phi', 'phi', 'phi', 'phi', 'phi']
# ['sunny', 'warm', 'normal', 'strong', 'warm', 'same']
# ['sunny', 'warm', 'high', 'strong', 'warm', 'same']
# ['sunny', 'warm', 'high', 'strong', 'cool', 'change']
